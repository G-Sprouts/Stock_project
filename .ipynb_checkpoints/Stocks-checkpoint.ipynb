# %%
# Create Machine Learning Model from stock metric data

# Import necessary libraries & modules


import pandas as pd
import csv
import math
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches
import seaborn as sb

from sklearn.pipeline import Pipeline
from sklearn.inspection import permutation_importance
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression, SGDRegressor

# %%
# Import .csv file 
# Create DataFrame from .csv file

file = pd.read_csv('/Users/garrettwankel/PycharmProjects/New/Final_df.csv')
df = pd.DataFrame(file)

# %%
# Examine DataFrame

df.tail()
# Out:
#                   Sym      SP  50-Day MA  200-Day MA        52W Range      MC  \
# 351  02-25-2021  imvt   15.94      33.04       39.66     8.34 - 53.75   1.77B
# 352  02-27-2021  snow  259.54     288.28      281.22  208.55 - 429.00  73.48B
# 353  02-27-2021  ccxi   67.84      63.04       57.40    30.72 - 70.29   4.70B
# 354  02-27-2021  gwph  214.25     178.78      126.24   67.98 - 217.50   6.64B
# 355  02-27-2021  imvt   15.78      30.67       39.49     8.34 - 53.75   1.55B
#
#        P/B        Vol Avg Vol (3m) Avg Vol (10-day)  Sh Out   Float Insiders  \
# 351   4.28    778,750        1.09M            2.76M  97.97M   33.5M   60.45%
# 352  14.79  2,535,551        4.86M            2.85M   50.7M  36.39M    0.00%
# 353  11.60    416,099      513.35k          485.01k  69.21M  48.17M   23.49%
# 354   9.06  1,035,426      860.72k          952.91k  31.34M  30.59M    0.64%
# 355   3.73    842,546        1.11M            1.43M  97.97M   33.5M   60.45%
#
#     Institutions
# 351       40.74%
# 352       96.59%
# 353       81.82%
# 354       84.41%
# 355       40.74%

# %%
# Rename column(s)

df.rename(columns={' ': 'Date'}, inplace=True)

# %%
# Examine datatypes to understand what needs to be converted to numerical values

df.dtypes
# Out:
# Date                 object
# Sym                  object
# SP                  float64
# 50-Day MA           float64
# 200-Day MA          float64
# 52W Range            object
# MC                   object
# P/B                 float64
# Vol                  object
# Avg Vol (3m)         object
# Avg Vol (10-day)     object
# Sh Out               object
# Float                object
# Insiders             object
# Institutions         object
# dtype: object

# %%
# Subset DataFrame for ML model implementation
# Reset index of Subset

df2 = df[df['Sym'] == 'ccxi']
df2.reset_index(inplace=True)

df2
# Out:
#     index        Date   Sym     SP  50-Day MA  200-Day MA      52W Range  \
# 0       1  08-07-2020  ccxi  55.24      56.30       50.83   6.37 - 65.43
# 1       6  08-06-2020  ccxi  54.49      56.48       50.81   6.37 - 65.43
# 2      11  08-11-2020  ccxi  53.66      56.08       51.09   6.37 - 65.43
# 3      15  08-12-2020  ccxi  52.99      55.94       51.18   6.37 - 65.43
# 4      19  08-17-2020  ccxi  52.20      55.69       51.45   6.44 - 65.43
# ..    ...         ...   ...    ...        ...         ...            ...
# 84    337  02-19-2021  ccxi  67.62      61.70       56.85  30.72 - 70.29
# 85    341  02-22-2021  ccxi  67.08      61.87       56.97  30.72 - 70.29
# 86    345  02-24-2021  ccxi  67.58      62.24       57.15  30.72 - 70.29
# 87    349  02-25-2021  ccxi  65.87      62.54       57.22  30.72 - 70.29
# 88    353  02-27-2021  ccxi  67.84      63.04       57.40  30.72 - 70.29
#
#        MC    P/B      Vol Avg Vol (3m) Avg Vol (10-day)  Sh Out   Float  \
# 0   3.75B  62.41  366,281      732.02k          624.86k  67.83M  43.42M
# 1   3.75B  62.41  307,348      729.32k          618.49k  67.83M  43.42M
# 2   3.70B  61.44  667,594      734.93k          455.33k  67.83M  48.08M
# 3   3.70B   8.78  947,420      734.64k          485.66k  68.89M  48.08M
# 4   3.67B   8.71  699,339      721.19k          544.63k  68.89M  47.82M
# ..    ...    ...      ...          ...              ...     ...     ...
# 84  4.29B  10.60  529,150      509.59k          364.57k  69.21M  48.17M
# 85  4.29B  10.60  314,438      516.03k           432.1k  69.21M  48.17M
# 86  4.29B  10.60  376,253      515.77k          474.35k  69.21M  48.17M
# 87  4.29B  10.60  364,919      514.65k          463.11k  69.21M  48.17M
# 88  4.70B  11.60  416,099      513.35k          485.01k  69.21M  48.17M
#
#    Insiders Institutions
# 0    28.93%       67.08%
# 1    28.93%       67.08%
# 2    28.93%       67.08%
# 3    28.93%       67.08%
# 4    28.93%       67.08%
# ..      ...          ...
# 84   23.49%       81.82%
# 85   23.49%       81.82%
# 86   23.49%       81.82%
# 87   23.49%       81.82%
# 88   23.49%       81.82%
#
# [89 rows x 16 columns]

# %%
# Remove non-numerical characters from featured columns for uniformity
# Convert object .dtype to float

df2['Vol'] = df2['Vol'].str.replace(',', '').astype(float)
# Out:
# /Users/garrettwankel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df2['Avg Vol (3m)'] = df2['Avg Vol (3m)'].str.replace('k', '', regex=True).str.replace('M', '', regex=True).astype(float)

df2['Avg Vol (10-day)'] = df2['Avg Vol (10-day)'].str.replace('k', '', regex=True).str.replace('M', '', regex=True).astype(float)
# Out:
# /Users/garrettwankel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/garrettwankel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2['Vol'].sort_values(ascending=True)
# Out:
# 11     192337.0
# 81     243340.0
# 82     243340.0
# 7      255563.0
# 55     260471.0
#         ...
# 32    1016965.0
# 67    1053785.0
# 65    1310108.0
# 24    1893856.0
# 47    2437456.0
# Name: Vol, Length: 89, dtype: float64

# %%
df2['Avg Vol (3m)'].sort_values(ascending=True)
# Out:
# 83    507.26
# 82    507.26
# 81    507.26
# 84    509.59
# 88    513.35
#        ...
# 4     721.19
# 1     729.32
# 0     732.02
# 3     734.64
# 2     734.93
# Name: Avg Vol (3m), Length: 89, dtype: float64

# %%
# Define features variables

X = df2[['50-Day MA', '200-Day MA', 'Vol', 'Avg Vol (10-day)']]
X2 = X.loc[:]
y = df2['SP']
y2 = y.loc[:]

# %%
X2
# Out:
#     50-Day MA  200-Day MA       Vol  Avg Vol (10-day)
# 0       56.30       50.83  366281.0            624.86
# 1       56.48       50.81  307348.0            618.49
# 2       56.08       51.09  667594.0            455.33
# 3       55.94       51.18  947420.0            485.66
# 4       55.69       51.45  699339.0            544.63
# ..        ...         ...       ...               ...
# 84      61.70       56.85  529150.0            364.57
# 85      61.87       56.97  314438.0            432.10
# 86      62.24       57.15  376253.0            474.35
# 87      62.54       57.22  364919.0            463.11
# 88      63.04       57.40  416099.0            485.01
#
# [89 rows x 4 columns]

# %%
X2.shape, y.shape
# Out:
# ((89, 4), (89,))

# %%
plt.plot(X2)
plt.show()

# %%
# Split dataset into train & test, specify test_size
X = np.array(X2)
y = np.array(y2)

y = y.reshape(y.shape[0],1)

y = np.ravel(y)
scaler = StandardScaler()


train_X, test_x, train_y, test_y = train_test_split(X, y, test_size=.20, random_state=10)

# %%
#train_X = scaler.fit_transform(train_X)
#test_x = scaler.transform(test_x)

# %%
# Create function to determine best 'max_leaf_nodes' value for each model
# Create for loop to iterate through list of possible values
# Print 'max_leaf_nodes' with corresponding 'mean_absolute_error'

def get_mae(max_leaf_nodes, train_X, test_x, train_y, test_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes)
    model2 = RandomForestRegressor(max_leaf_nodes=max_leaf_nodes)
    model3 = LinearRegression()
    model4 = Pipeline([('ss', scaler), ('sgd', SGDRegressor())])
    #pipe = Pipeline([('forest', RandomForestRegressor())])
    model.fit(train_X, train_y)
    model2.fit(train_X, train_y)
    model3.fit(train_X, train_y)
    model4.fit(train_X, train_y)
    preds1 = model.predict(test_x)
    preds2 = model2.predict(test_x)
    preds3 = model3.predict(test_x)
    preds4 = model4.predict(test_x)
    mae1 = mean_absolute_error(preds1, test_y)
    mae2 = mean_absolute_error(preds2, test_y)
    mae3 = mean_absolute_error(preds3, test_y)
    mae4 = mean_absolute_error(preds4, test_y)
    return(mae1, mae2, mae3, mae4)

for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, test_x, train_y, test_y)
    print(max_leaf_nodes, my_mae)
# Out:
# 5 (2.402569444444444, 2.0779881188841944, 2.6131542168110204, 2.589979934644147)
# 50 (2.4172222222222217, 1.9854916666666742, 2.6131542168110204, 2.6068095490469636)
# 500 (1.9422222222222214, 1.9294277777777795, 2.6131542168110204, 2.611895541983722)
# 5000 (1.8844444444444437, 1.845344444444445, 2.6131542168110204, 2.6104814157090876)

# %%
# Create models for predicting
# Train models

model = DecisionTreeRegressor(max_leaf_nodes=5000)
model2 = RandomForestRegressor(max_leaf_nodes=500, n_estimators=500, criterion='mae')
model3 = LinearRegression()
model4 = SGDRegressor()
model.fit(train_X,train_y)
model2.fit(train_X, train_y)
model3.fit(train_X, train_y)
model4.fit(train_X, train_y)
# Out:
# SGDRegressor()

# %%
# Lists of values

preds = []
pre_maes = []
pre_stds = []
r_maes = []
r_stds = []

# %%
# Make predictions

preds1 = model.predict(test_x)
preds2 = model2.predict(test_x)
preds3 = model3.predict(test_x)
preds4 = model4.predict(test_x)

preds.append(preds1)
preds.append(preds2)
preds.append(preds3)
preds.append(preds4)

# %%
# Score each model to determine it's accuracy based on the returned coeeficient

print(model.score(test_x, test_y))
print(model2.score(test_x, test_y))
print(model3.score(test_x, test_y))
print(model4.score(test_x, test_y))
# Out:
# 0.34439353711905263
# 0.6656186388527031
# 0.48969022451982946
# -4.742540276102461e+39

# %%
# Find the 'mean abosolute error' of each model
# ** Helpful to determine how accurate model is **

mae1 = mean_absolute_error(test_y, preds1)
mae2 = mean_absolute_error(test_y, preds2)
mae3 = mean_absolute_error(test_y, preds3)
mae4 = mean_absolute_error(test_y, preds4)

pre_maes.append(mae1)
pre_maes.append(mae2)
pre_maes.append(mae3)
pre_maes.append(mae4)

# %%
std1 = mean_squared_error(test_y, preds1)
std2 = mean_squared_error(test_y, preds2)
std3 = mean_squared_error(test_y, preds3)
std4 = mean_squared_error(test_y, preds4)

pre_stds.append(std1)
pre_stds.append(std2)
pre_stds.append(std3)
pre_stds.append(std4)

# %%
score = cross_val_score(model, X, y, cv=5)
score
# Out:
# array([ -5.84562301,  -0.76390782,  -2.25076664, -11.05732007,
#         -1.71929378])

# %%
x=len(test_y)

# %%
x
# Out:
# 18

# %%
#plt.figure(figsize=(25,12))
#plt.plot(test_y)
#plt.plot(preds1)
#plt.plot(preds2)
#plt.plot(preds3)

titles = ['DR Regressor', 'RF Regressor', 'L Regression', 'SGD Regressor']
x=range(len(test_y+1))



fig, axs = plt.subplots(1,4)
axs[0].plot(x, test_y, x, preds1, marker='o')
axs[1].plot(x, test_y, x, preds2, marker='o')
axs[2].plot(x, test_y, x, preds3, marker='o')
axs[3].plot(x, test_y, x, preds4, marker='o')


fig.subplots_adjust(right=4)

plt.show()

#red = mpatches.Patch(color='red', label='Test data')
#blue = mpatches.Patch(color='blue', label='DCR')
#green = mpatches.Patch(color='green', label='RF')
#orange = mpatches.Patch(color='orange', label='LR')
#plt.legend(handles=[red, blue, green, orange])
#plt.show()

# %%
titles = ['DR Regressor', 'RF Regressor', 'L Regression', 'SGD Regressor']
test_set = 'Test values'


def stock_plot(pred, title, r_mae, r_std):

    x = range(len(test_y))
    ax = plt.subplot(1,1,1)
    ax.plot(x, test_y, x, pred, marker='o')
    ax.set_title('Model: ' + title)
    
    legend_1 = ax.legend(labels=[test_set, 'model'])
    axs = plt.gca().add_artist(legend_1)
    #ax.text(.9, 33, s= 'mae: '+str(r_mae) + ' std: '+str(r_std), bbox=dict(edgecolor='black', facecolor='white', alpha=0.5))
    plt.tight_layout()
    plt.show()

def rounder(mae, std):
    r_mae = round(mae, 3)
    r_std = round(std, 3)
    r_maes.append(r_mae)
    r_stds.append(r_std)
    
for mae, std in zip(pre_maes, pre_stds):
    rounder(mae, std)

for pred, title, r_mae, r_std in zip(preds, titles, r_maes, r_stds):
    stock_plot(pred, title, r_mae, r_std)

# %%
result = permutation_importance(model4, test_x, test_y, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()

# %%
result
# Out:
# {'importances_mean': array([ 5.96309346e+30,  4.20186982e+30, -7.28675773e+33, -1.59335688e+34]),
#  'importances_std': array([6.60554139e+30, 6.01203526e+30, 1.96807415e+34, 2.60175005e+34]),
#  'importances': array([[ 1.56871399e+31,  3.22194447e+30, -1.64192013e+30,
#           2.43930826e+30,  1.66647982e+31,  4.54739744e+30,
#           5.49040975e+30,  1.99591356e+30, -2.48856231e+30,
#           1.37145054e+31],
#         [ 1.48586225e+31,  4.81050685e+30, -5.49145063e+30,
#          -7.93654965e+29,  3.88072986e+30,  6.83793771e+30,
#          -2.67200714e+30,  3.72320864e+30,  4.05821528e+30,
#           1.28065900e+31],
#         [ 2.79420935e+34, -1.07442977e+34, -2.54973010e+34,
#          -7.58299021e+33, -2.17904612e+34, -2.40834068e+34,
#           1.63873389e+34, -3.65853192e+34,  1.15190483e+34,
#          -2.43228182e+33],
#         [-3.42460043e+33, -3.85308812e+34, -1.40354498e+34,
#           7.80529068e+33, -1.83435183e+34, -1.91130235e+34,
#          -6.26326972e+34,  3.22411583e+34, -4.34677984e+34,
#           1.65831731e+32]])}

# %%
result.importances[sorted_idx].T
# Out:
# array([[-3.42460043e+33,  2.79420935e+34,  1.48586225e+31,
#          1.56871399e+31],
#        [-3.85308812e+34, -1.07442977e+34,  4.81050685e+30,
#          3.22194447e+30],
#        [-1.40354498e+34, -2.54973010e+34, -5.49145063e+30,
#         -1.64192013e+30],
#        [ 7.80529068e+33, -7.58299021e+33, -7.93654965e+29,
#          2.43930826e+30],
#        [-1.83435183e+34, -2.17904612e+34,  3.88072986e+30,
#          1.66647982e+31],
#        [-1.91130235e+34, -2.40834068e+34,  6.83793771e+30,
#          4.54739744e+30],
#        [-6.26326972e+34,  1.63873389e+34, -2.67200714e+30,
#          5.49040975e+30],
#        [ 3.22411583e+34, -3.65853192e+34,  3.72320864e+30,
#          1.99591356e+30],
#        [-4.34677984e+34,  1.15190483e+34,  4.05821528e+30,
#         -2.48856231e+30],
#        [ 1.65831731e+32, -2.43228182e+33,  1.28065900e+31,
#          1.37145054e+31]])
